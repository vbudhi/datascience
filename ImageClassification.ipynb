# %% [markdown]
# ## Image Classification
# A quick example on how to use the visual recognition API to classify images

# %%
# Install the API
# !pip install --upgrade "watson-developer-cloud>=1.0,<2.0"
# Out:
# Collecting watson-developer-cloud<2.0,>=1.0
#   Downloading https://files.pythonhosted.org/packages/4f/b5/d2242076082287db54ba04b435cf288b0fd03e767faf34df70d809cec404/watson-developer-cloud-1.3.3.tar.gz (177kB)
#     100% |████████████████████████████████| 184kB 4.6MB/s eta 0:00:01
# Requirement not upgraded as not directly required: requests<3.0,>=2.0 in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from watson-developer-cloud<2.0,>=1.0)
# Requirement not upgraded as not directly required: python_dateutil>=2.5.3 in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from watson-developer-cloud<2.0,>=1.0)
# Collecting autobahn>=0.10.9 (from watson-developer-cloud<2.0,>=1.0)
#   Downloading https://files.pythonhosted.org/packages/ec/80/b1172311d09f7b1b27f9260e21fc4374c4b72ad1ad1c87862e8f364d8b67/autobahn-18.4.1-py2.py3-none-any.whl (293kB)
#     100% |████████████████████████████████| 296kB 3.0MB/s eta 0:00:01
# Collecting Twisted>=13.2.0 (from watson-developer-cloud<2.0,>=1.0)
#   Downloading https://files.pythonhosted.org/packages/12/2a/e9e4fb2e6b2f7a75577e0614926819a472934b0b85f205ba5d5d2add54d0/Twisted-18.4.0.tar.bz2 (3.0MB)
#     100% |████████████████████████████████| 3.0MB 268kB/s eta 0:00:01
# Requirement not upgraded as not directly required: pyOpenSSL>=16.2.0 in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from watson-developer-cloud<2.0,>=1.0)
# Collecting service-identity>=17.0.0 (from watson-developer-cloud<2.0,>=1.0)
#   Downloading https://files.pythonhosted.org/packages/29/fa/995e364220979e577e7ca232440961db0bf996b6edaf586a7d1bd14d81f1/service_identity-17.0.0-py2.py3-none-any.whl
# Requirement not upgraded as not directly required: chardet<3.1.0,>=3.0.2 in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from requests<3.0,>=2.0->watson-developer-cloud<2.0,>=1.0)
# Requirement not upgraded as not directly required: idna<2.7,>=2.5 in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from requests<3.0,>=2.0->watson-developer-cloud<2.0,>=1.0)
# Requirement not upgraded as not directly required: urllib3<1.23,>=1.21.1 in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from requests<3.0,>=2.0->watson-developer-cloud<2.0,>=1.0)
# Requirement not upgraded as not directly required: certifi>=2017.4.17 in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from requests<3.0,>=2.0->watson-developer-cloud<2.0,>=1.0)
# Requirement not upgraded as not directly required: six>=1.5 in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from python_dateutil>=2.5.3->watson-developer-cloud<2.0,>=1.0)
# Collecting txaio>=2.10.0 (from autobahn>=0.10.9->watson-developer-cloud<2.0,>=1.0)
#   Downloading https://files.pythonhosted.org/packages/dc/2e/c8a877b0a5c2798fa93ebcc1465a72a68c089e5f8b0a852ca335751dcc5a/txaio-2.10.0-py2.py3-none-any.whl
# Collecting zope.interface>=4.4.2 (from Twisted>=13.2.0->watson-developer-cloud<2.0,>=1.0)
#   Downloading https://files.pythonhosted.org/packages/ac/8a/657532df378c2cd2a1fe6b12be3b4097521570769d4852ec02c24bd3594e/zope.interface-4.5.0.tar.gz (151kB)
#     100% |████████████████████████████████| 153kB 6.0MB/s eta 0:00:01
# Collecting constantly>=15.1 (from Twisted>=13.2.0->watson-developer-cloud<2.0,>=1.0)
#   Downloading https://files.pythonhosted.org/packages/b9/65/48c1909d0c0aeae6c10213340ce682db01b48ea900a7d9fce7a7910ff318/constantly-15.1.0-py2.py3-none-any.whl
# Collecting incremental>=16.10.1 (from Twisted>=13.2.0->watson-developer-cloud<2.0,>=1.0)
#   Downloading https://files.pythonhosted.org/packages/f5/1d/c98a587dc06e107115cf4a58b49de20b19222c83d75335a192052af4c4b7/incremental-17.5.0-py2.py3-none-any.whl
# Collecting Automat>=0.3.0 (from Twisted>=13.2.0->watson-developer-cloud<2.0,>=1.0)
#   Downloading https://files.pythonhosted.org/packages/17/6a/1baf488c2015ecafda48c03ca984cf0c48c254622668eb1732dbe2eae118/Automat-0.6.0-py2.py3-none-any.whl
# Collecting hyperlink>=17.1.1 (from Twisted>=13.2.0->watson-developer-cloud<2.0,>=1.0)
#   Downloading https://files.pythonhosted.org/packages/a7/b6/84d0c863ff81e8e7de87cff3bd8fd8f1054c227ce09af1b679a8b17a9274/hyperlink-18.0.0-py2.py3-none-any.whl
# Requirement not upgraded as not directly required: cryptography>=1.9 in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from pyOpenSSL>=16.2.0->watson-developer-cloud<2.0,>=1.0)
# Collecting pyasn1 (from service-identity>=17.0.0->watson-developer-cloud<2.0,>=1.0)
#   Downloading https://files.pythonhosted.org/packages/ba/fe/02e3e2ee243966b143657fb8bd6bc97595841163b6d8c26820944acaec4d/pyasn1-0.4.2-py2.py3-none-any.whl (71kB)
#     100% |████████████████████████████████| 71kB 8.4MB/s eta 0:00:01
# Collecting attrs (from service-identity>=17.0.0->watson-developer-cloud<2.0,>=1.0)
#   Downloading https://files.pythonhosted.org/packages/41/59/cedf87e91ed541be7957c501a92102f9cc6363c623a7666d69d51c78ac5b/attrs-18.1.0-py2.py3-none-any.whl
# Collecting pyasn1-modules (from service-identity>=17.0.0->watson-developer-cloud<2.0,>=1.0)
#   Downloading https://files.pythonhosted.org/packages/e9/51/bcd96bf6231d4b2cc5e023c511bee86637ba375c44a6f9d1b4b7ad1ce4b9/pyasn1_modules-0.2.1-py2.py3-none-any.whl (60kB)
#     100% |████████████████████████████████| 61kB 8.5MB/s eta 0:00:01
# Requirement not upgraded as not directly required: setuptools in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from zope.interface>=4.4.2->Twisted>=13.2.0->watson-developer-cloud<2.0,>=1.0)
# Requirement not upgraded as not directly required: asn1crypto>=0.21.0 in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from cryptography>=1.9->pyOpenSSL>=16.2.0->watson-developer-cloud<2.0,>=1.0)
# Requirement not upgraded as not directly required: cffi>=1.7 in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from cryptography>=1.9->pyOpenSSL>=16.2.0->watson-developer-cloud<2.0,>=1.0)
# Requirement not upgraded as not directly required: pycparser in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from cffi>=1.7->cryptography>=1.9->pyOpenSSL>=16.2.0->watson-developer-cloud<2.0,>=1.0)
# Building wheels for collected packages: watson-developer-cloud, Twisted, zope.interface
#   Running setup.py bdist_wheel for watson-developer-cloud ... done
#   Stored in directory: /home/dsxuser/.cache/pip/wheels/7a/45/e3/4124673ac1081eefdae4e6a220e52ce84996fc808044d85c28
#   Running setup.py bdist_wheel for Twisted ... done
#   Stored in directory: /home/dsxuser/.cache/pip/wheels/b3/76/f7/85353c829c0881e74b5366ce0ed59042b098bb4903e2da8828
#   Running setup.py bdist_wheel for zope.interface ... done
#   Stored in directory: /home/dsxuser/.cache/pip/wheels/c6/b2/d2/be6785a207eaa58d76debc10c9d5c66196b40a88abb61d6af7
# Successfully built watson-developer-cloud Twisted zope.interface
# Installing collected packages: txaio, autobahn, zope.interface, constantly, incremental, attrs, Automat, hyperlink, Twisted, pyasn1, pyasn1-modules, service-identity, watson-developer-cloud
# Successfully installed Automat-0.6.0 Twisted-18.4.0 attrs-18.1.0 autobahn-18.4.1 constantly-15.1.0 hyperlink-18.0.0 incremental-17.5.0 pyasn1-0.4.2 pyasn1-modules-0.2.1 service-identity-17.0.0 txaio-2.10.0 watson-developer-cloud-1.3.3 zope.interface-4.5.0

# %% [markdown]
# ### API key
# Make sure to change the API key to the value from your own service

# %%
# Key form the service credentials
watson_api_key='1256795a98f8f0d4f8416b3b2614d1814fbec5ce'

# %%
# Create the interface object
import json
from watson_developer_cloud import VisualRecognitionV3

visual_recognition = VisualRecognitionV3(
    '2016-05-20',
    api_key=watson_api_key
)

# %% [markdown]
# ## Access local files
# The local files are stored in the IBM Cloud Object Storage.<br/>
# IBM COS supports a common set of S3 API functions for programmatic access. Watson Studio can do most of the work of defining the access to your files.
#
# Use the empty cell below to insert code, let's say from "elantra.jpg", using the "Insert to code" button and the "Insert StreamingBody object".
#
# Compare the code to the next cell and modify it.<br/>
#  - Copy the first part of the cell and replace the content of the following one
#  - Copy the value of Bucket in the client_xxx*.getobject() call and replace the value of bucket in the next cell

# %%
import sys
import types
import pandas as pd
from botocore.client import Config
import ibm_boto3

def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share your notebook.
cos = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='K5vUyZlY3GTXLDEWIkCIBxYB-28SFbYoKEGFpW945w41',
    ibm_auth_endpoint="https://cos-service.bluemix.net/endpoints",
    config=Config(signature_version='oauth'),
    endpoint_url='s3-api.us-geo.objectstorage.softlayer.net')

Bucket='watsonstudiodemoc9a00acb2dec4d099daf671c0d2f49f4'
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-971acc3cb9d5> in <module>()
#      14     ibm_auth_endpoint="https://cos-service.bluemix.net/endpoints",
#      15     config=Config(signature_version='oauth'),
# ---> 16     endpoint_url='s3-api.us-geo.objectstorage.softlayer.net')
#      17
#      18 Bucket='watsonstudiodemoc9a00acb2dec4d099daf671c0d2f49f4'
#
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/ibm_boto3/__init__.py in client(*args, **kwargs)
#      81     See :py:meth:`boto3.session.Session.client`.
#      82     """
# ---> 83     return _get_default_session().client(*args, **kwargs)
#      84
#      85
#
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/ibm_boto3/session.py in client(self, service_name, region_name, api_version, use_ssl, verify, endpoint_url, aws_access_key_id, aws_secret_access_key, aws_session_token, ibm_api_key_id, ibm_service_instance_id, ibm_auth_endpoint, auth_function, token_manager, config)
#     312             ibm_api_key_id=ibm_api_key_id, ibm_service_instance_id=ibm_service_instance_id,
#     313             ibm_auth_endpoint=ibm_auth_endpoint, auth_function=auth_function,
# --> 314             token_manager=token_manager, config=config)
#     315
#     316     def resource(self, service_name, region_name=None, api_version=None,
#
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/ibm_botocore/session.py in create_client(self, service_name, region_name, api_version, use_ssl, verify, endpoint_url, aws_access_key_id, aws_secret_access_key, aws_session_token, ibm_api_key_id, ibm_service_instance_id, ibm_auth_endpoint, auth_function, token_manager, config)
#     899             is_secure=use_ssl, endpoint_url=endpoint_url, verify=verify,
#     900             credentials=credentials, scoped_config=self.get_scoped_config(),
# --> 901             client_config=config, api_version=api_version)
#     902
#     903         # Register custom callbacks
#
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/ibm_botocore/client.py in create_client(self, service_name, region_name, is_secure, endpoint_url, verify, credentials, scoped_config, api_version, client_config)
#      68         client_args = self._get_client_args(
#      69             service_model, region_name, is_secure, endpoint_url,
# ---> 70             verify, credentials, scoped_config, client_config, endpoint_bridge)
#      71         service_client = cls(**client_args)
#      72         self._register_s3_events(service_client, endpoint_bridge, endpoint_url)
#
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/ibm_botocore/client.py in _get_client_args(self, service_model, region_name, is_secure, endpoint_url, verify, credentials, scoped_config, client_config, endpoint_bridge)
#     222         return args_creator.get_client_args(
#     223             service_model, region_name, is_secure, endpoint_url,
# --> 224             verify, credentials, scoped_config, client_config, endpoint_bridge)
#     225
#     226     def _create_methods(self, service_model):
#
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/ibm_botocore/args.py in get_client_args(self, service_model, region_name, is_secure, endpoint_url, verify, credentials, scoped_config, client_config, endpoint_bridge)
#      69             response_parser_factory=self._response_parser_factory,
#      70             max_pool_connections=new_config.max_pool_connections,
# ---> 71             timeout=(new_config.connect_timeout, new_config.read_timeout))
#      72
#      73         serializer = ibm_botocore.serialize.create_serializer(
#
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/ibm_botocore/endpoint.py in create_endpoint(self, service_model, region_name, endpoint_url, verify, response_parser_factory, timeout, max_pool_connections)
#     270         if not is_valid_endpoint_url(endpoint_url):
#     271
# --> 272             raise ValueError("Invalid endpoint: %s" % endpoint_url)
#     273         return Endpoint(
#     274             endpoint_url,
#
# ValueError: Invalid endpoint: s3-api.us-geo.objectstorage.softlayer.net

# %%
# Create a zip files with the three images we want to classify
res=cos.download_file(Bucket=Bucket,Key='orange-bmw-m3-coupe.jpg',Filename='orange-bmw-m3-coupe.jpg')
res=cos.download_file(Bucket=Bucket,Key='volvo-x90-suv.jpg',Filename='volvo-x90-suv.jpg')
res=cos.download_file(Bucket=Bucket,Key='elantra.jpg',Filename='elantra.jpg')
# !zip cars.zip *.jpg
# Out:
# ---------------------------------------------------------------------------
# CredentialRetrievalError                  Traceback (most recent call last)
# <ipython-input-11-961bb4216210> in <module>()
#       1 # Create a zip files with the three images we want to classify
# ----> 2 res=cos.download_file(Bucket=Bucket,Key='orange-bmw-m3-coupe.jpg',Filename='orange-bmw-m3-coupe.jpg')
#       3 res=cos.download_file(Bucket=Bucket,Key='volvo-x90-suv.jpg',Filename='volvo-x90-suv.jpg')
#       4 res=cos.download_file(Bucket=Bucket,Key='elantra.jpg',Filename='elantra.jpg')
#       5 get_ipython().system('zip cars.zip *.jpg')
#
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/ibm_boto3/s3/inject.py in download_file(self, Bucket, Key, Filename, ExtraArgs, Callback, Config)
#     124         return transfer.download_file(
#     125             bucket=Bucket, key=Key, filename=Filename,
# --> 126             extra_args=ExtraArgs, callback=Callback)
#     127
#     128
#
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/ibm_boto3/s3/transfer.py in download_file(self, bucket, key, filename, extra_args, callback)
#     297             bucket, key, filename, extra_args, subscribers)
#     298         try:
# --> 299             future.result()
#     300         # This is for backwards compatibility where when retries are
#     301         # exceeded we need to throw the same error from ibm_boto3 instead of
#
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/ibm_s3transfer/futures.py in result(self)
#      71             # however if a KeyboardInterrupt is raised we want want to exit
#      72             # out of this and propogate the exception.
# ---> 73             return self._coordinator.result()
#      74         except KeyboardInterrupt as e:
#      75             self.cancel()
#
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/ibm_s3transfer/futures.py in result(self)
#     231         # final result.
#     232         if self._exception:
# --> 233             raise self._exception
#     234         return self._result
#     235
#
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/ibm_s3transfer/tasks.py in _main(self, transfer_future, **kwargs)
#     253             # Call the submit method to start submitting tasks to execute the
#     254             # transfer.
# --> 255             self._submit(transfer_future=transfer_future, **kwargs)
#     256         except BaseException as e:
#     257             # If there was an exception raised during the submission of task
#
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/ibm_s3transfer/download.py in _submit(self, client, config, osutil, request_executor, io_executor, transfer_future)
#     347                 Bucket=transfer_future.meta.call_args.bucket,
#     348                 Key=transfer_future.meta.call_args.key,
# --> 349                 **transfer_future.meta.call_args.extra_args
#     350             )
#     351             transfer_future.meta.provide_transfer_size(
#
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/ibm_botocore/client.py in _api_call(self, *args, **kwargs)
#     251                     "%s() only accepts keyword arguments." % py_operation_name)
#     252             # The "self" in this scope is referring to the BaseClient.
# --> 253             return self._make_api_call(operation_name, kwargs)
#     254
#     255         _api_call.__name__ = str(py_operation_name)
#
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/ibm_botocore/client.py in _make_api_call(self, operation_name, api_params)
#     528         else:
#     529             http, parsed_response = self._endpoint.make_request(
# --> 530                 operation_model, request_dict)
#     531
#     532         self.meta.events.emit(
#
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/ibm_botocore/endpoint.py in make_request(self, operation_model, request_dict)
#     139         logger.debug("Making request for %s (verify_ssl=%s) with params: %s",
#     140                      operation_model, self.verify, request_dict)
# --> 141         return self._send_request(request_dict, operation_model)
#     142
#     143     def create_request(self, params, operation_model=None):
#
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/ibm_botocore/endpoint.py in _send_request(self, request_dict, operation_model)
#     164     def _send_request(self, request_dict, operation_model):
#     165         attempts = 1
# --> 166         request = self.create_request(request_dict, operation_model)
#     167         success_response, exception = self._get_response(
#     168             request, operation_model, attempts)
#
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/ibm_botocore/endpoint.py in create_request(self, params, operation_model)
#     148                 op_name=operation_model.name)
#     149             self._event_emitter.emit(event_name, request=request,
# --> 150                                      operation_name=operation_model.name)
#     151         prepared_request = self.prepare_request(request)
#     152         return prepared_request
#
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/ibm_botocore/hooks.py in emit(self, event_name, **kwargs)
#     225                  handlers.
#     226         """
# --> 227         return self._emit(event_name, kwargs)
#     228
#     229     def emit_until_response(self, event_name, **kwargs):
#
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/ibm_botocore/hooks.py in _emit(self, event_name, kwargs, stop_on_response)
#     208         for handler in handlers_to_call:
#     209             logger.debug('Event %s: calling handler %s', event_name, handler)
# --> 210             response = handler(**kwargs)
#     211             responses.append((handler, response))
#     212             if stop_on_response and response is not None:
#
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/ibm_botocore/signers.py in handler(self, operation_name, request, **kwargs)
#      88         # this method is invoked to sign the request.
#      89         # Don't call this method directly.
# ---> 90         return self.sign(operation_name, request)
#      91
#      92     def sign(self, operation_name, request, region_name=None,
#
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/ibm_botocore/signers.py in sign(self, operation_name, request, region_name, signing_type, expires_in)
#     137
#     138             try:
# --> 139                 auth = self.get_auth_instance(**kwargs)
#     140             except UnknownSignatureVersionError as e:
#     141                 if signing_type != 'standard':
#
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/ibm_botocore/signers.py in get_auth_instance(self, signing_name, region_name, signature_version, **kwargs)
#     216         frozen_credentials = None
#     217         if self._credentials is not None:
# --> 218             frozen_credentials = self._credentials.get_frozen_credentials()
#     219         kwargs['credentials'] = frozen_credentials
#     220         if cls.REQUIRES_REGION:
#
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/ibm_botocore/credentials.py in get_frozen_credentials(self)
#     675
#     676         """
# --> 677         token = self.token_manager.get_token()
#     678
#     679         # Signer is only interested in token, and besides, we might not even have api key
#
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/ibm_botocore/credentials.py in get_token(self)
#     353
#     354         """
# --> 355         self._refresh(can_retry=True)
#     356         self._set_refresh_timeouts()
#     357
#
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/ibm_botocore/credentials.py in _refresh(self, can_retry)
#     472                 is_mandatory_refresh = self._refresh_needed(
#     473                     self._mandatory_refresh_timeout)
# --> 474                 self._protected_refresh(is_mandatory=is_mandatory_refresh, can_retry=can_retry)
#     475                 return
#     476             finally:
#
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/ibm_botocore/credentials.py in _protected_refresh(self, is_mandatory, can_retry)
#     493         while True:
#     494             try:
# --> 495                 metadata = self.auth_function()
#     496                 break
#     497             except Exception as e:
#
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/ibm_botocore/credentials.py in _default_auth_function(self)
#     397         if response.status_code != httplib.OK:
#     398             _msg = 'HttpCode({code}) - Retrieval of tokens from server failed.'.format(code=response.status_code)
# --> 399             raise CredentialRetrievalError(provider=self._get_token_url(), error_msg=_msg)
#     400
#     401         return json.loads(response.content.decode('utf-8'))
#
# CredentialRetrievalError: Error when retrieving credentials from https://cos-service.bluemix.net/endpoints: HttpCode(404) - Retrieval of tokens from server failed.

# %% [markdown]
# ## Calling the classifier
# First, replace the classifier ID with the ID of your classifier
#
# You will execute the next two cells twice:
# - With the classifier_ids parameter commented out.<br/>
# This will show results with the generic classifier that is part of the service
# - Uncomment the classifier_ids and execute again<br/>
# This time, you get the results from your classifier
#
# Note that both classifier ('default' and your own) can be used at the same time.

# %%
# Classify the images and print out partial results for readability
car_1=open("./cars.zip", 'rb')
classes = visual_recognition.classify(
        car_1,
        parameters=json.dumps({
            # 'classifier_ids': ['CarClassifier_837179912'],
            'threshold': 0.1
        }))
# print(json.dumps(classes, indent=2))
# Format the json output to be easier to read
for i in range(3):
    result = classes['images'][i]
    print ("Image: " + result['image'])
    print ("Class: " + str(result['classifiers'][0]['classes'][0]['class']))
    print ("Score: " + str(result['classifiers'][0]['classes'][0]['score']))
    print ("Classifier: " + str(result['classifiers'][0]['classifier_id']))
    print(" ")

# %%
# Print out the entire json file
print(json.dumps(classes, indent=2))

# %%
# remove the local files create earlier
# !rm *.zip *.jpg
